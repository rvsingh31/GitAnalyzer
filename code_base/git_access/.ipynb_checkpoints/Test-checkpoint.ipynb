# %%
import Use_Case
import os
import pandas as pd

# %%
repo_owner = 'mochajs'
git_url = 'git://github.com/mochajs/mocha.git'
repo_name = 'mocha'

# %%
ucase1 = Use_Case.Use_Case(repo_owner,repo_name,git_url)
# Out:
# d6a539ee2b083fcf5603d2bd61bc721c8c7bf11d

# %%
uc1 = ucase1.UC1()
print(uc1.columns)
# Out:
# Index(['FilePath', 'AuthorEmail', 'AuthorName', 'Score', 'LinesOfCode',
#        'FileSizeBytes', 'LastModified', 'RepoName', 'RepoUrl'],
#       dtype='object')

# %%
uc2 = ucase1.UC2()

# %%
uc3 = ucase1.UC3()

# %%
for _,row in uc1.iterrows():
    print(row)
# Out:
# FilePath         yard/template/default/layout/html/setup.rb
# AuthorEmail                            dchelimsky@gmail.com
# AuthorName                                  David Chelimsky
# Score                                                     6
# LinesOfCode                                               6
# FileSizeBytes                                           203
# LastModified                            2011-12-08 08:22:45
# RepoName                                        rspec-rails
# RepoUrl              git://github.com/rspec/rspec-rails.git
# Name: 1810, dtype: object
# FilePath         yard/template/default/fulldoc/html/css/rspec.css
# AuthorEmail                                  dchelimsky@gmail.com
# AuthorName                                        David Chelimsky
# Score                                                          24
# LinesOfCode                                                    20
# FileSizeBytes                                                 257
# LastModified                                  2011-12-08 09:21:48
# RepoName                                              rspec-rails
# RepoUrl                    git://github.com/rspec/rspec-rails.git
# Name: 1809, dtype: object
# FilePath                spec/support/shared_examples.rb
# AuthorEmail                     myron.marston@gmail.com
# AuthorName                                Myron Marston
# Score                                               214
# LinesOfCode                                          99
# FileSizeBytes                                      3293
# LastModified                        2014-06-15 12:26:59
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1808, dtype: object
# FilePath                spec/support/shared_examples.rb
# AuthorEmail                      aaron.kromer@gmail.com
# AuthorName                                 Aaron Kromer
# Score                                                16
# LinesOfCode                                          99
# FileSizeBytes                                      3293
# LastModified                        2014-06-15 12:26:59
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1807, dtype: object
# FilePath                    spec/support/null_object.rb
# AuthorEmail                         alindeman@gmail.com
# AuthorName                                Andy Lindeman
# Score                                                 6
# LinesOfCode                                           6
# FileSizeBytes                                        80
# LastModified                        2013-04-16 08:46:27
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1806, dtype: object
# FilePath                        spec/support/helpers.rb
# AuthorEmail                         hello@jonrowe.co.uk
# AuthorName                                     Jon Rowe
# Score                                             39.25
# LinesOfCode                                          14
# FileSizeBytes                                       373
# LastModified                        2015-02-02 12:11:38
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1802, dtype: object
# FilePath                        spec/support/helpers.rb
# AuthorEmail                     myron.marston@gmail.com
# AuthorName                                Myron Marston
# Score                                           15.4167
# LinesOfCode                                          14
# FileSizeBytes                                       373
# LastModified                        2015-02-02 12:11:38
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1804, dtype: object
# FilePath                        spec/support/helpers.rb
# AuthorEmail                      aaron.kromer@gmail.com
# AuthorName                                 Aaron Kromer
# Score                                                 6
# LinesOfCode                                          14
# FileSizeBytes                                       373
# LastModified                        2015-02-02 12:11:38
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1799, dtype: object
# FilePath                        spec/support/helpers.rb
# AuthorEmail                       andy@andylindeman.com
# AuthorName                                Andy Lindeman
# Score                                                 6
# LinesOfCode                                          14
# FileSizeBytes                                       373
# LastModified                        2015-02-02 12:11:38
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1800, dtype: object
# FilePath                        spec/support/helpers.rb
# AuthorEmail                        mikeastock@gmail.com
# AuthorName                                Michael Stock
# Score                                                 6
# LinesOfCode                                          14
# FileSizeBytes                                       373
# LastModified                        2015-02-02 12:11:38
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1803, dtype: object
# FilePath                        spec/support/helpers.rb
# AuthorEmail                          rr.rosas@gmail.com
# AuthorName                      Rodrigo Rosenfeld Rosas
# Score                                             0.875
# LinesOfCode                                          14
# FileSizeBytes                                       373
# LastModified                        2015-02-02 12:11:38
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1805, dtype: object
# FilePath                        spec/support/helpers.rb
# AuthorEmail                        dchelimsky@gmail.com
# AuthorName                              David Chelimsky
# Score                                          0.609375
# LinesOfCode                                          14
# FileSizeBytes                                       373
# LastModified                        2015-02-02 12:11:38
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1801, dtype: object
# FilePath                     spec/support/generators.rb
# AuthorEmail                          kohei.sg@gmail.com
# AuthorName                                   Kohei Sugi
# Score                                            72.625
# LinesOfCode                                         124
# FileSizeBytes                                      4168
# LastModified                        2019-02-12 04:57:53
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1796, dtype: object
# FilePath                     spec/support/generators.rb
# AuthorEmail                            nxlith@gmail.com
# AuthorName                                  Michel Ocon
# Score                                                24
# LinesOfCode                                         124
# FileSizeBytes                                      4168
# LastModified                        2019-02-12 04:57:53
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1798, dtype: object
# FilePath                     spec/support/generators.rb
# AuthorEmail                      aaron.kromer@gmail.com
# AuthorName                                 Aaron Kromer
# Score                                           1.14062
# LinesOfCode                                         124
# FileSizeBytes                                      4168
# LastModified                        2019-02-12 04:57:53
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1795, dtype: object
# FilePath                     spec/support/generators.rb
# AuthorEmail                          mail@jonrowe.co.uk
# AuthorName                                     Jon Rowe
# Score                                           1.14062
# LinesOfCode                                         124
# FileSizeBytes                                      4168
# LastModified                        2019-02-12 04:57:53
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1797, dtype: object
# FilePath                     spec/support/ar_classes.rb
# AuthorEmail                          mail@jonrowe.co.uk
# AuthorName                                     Jon Rowe
# Score                                                 8
# LinesOfCode                                          44
# FileSizeBytes                                       969
# LastModified                        2015-12-23 22:36:32
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1793, dtype: object
# FilePath                     spec/support/ar_classes.rb
# AuthorEmail                   samphippen@googlemail.com
# AuthorName                                  Sam Phippen
# Score                                                 8
# LinesOfCode                                          44
# FileSizeBytes                                       969
# LastModified                        2015-12-23 22:36:32
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1794, dtype: object
# FilePath                     spec/support/ar_classes.rb
# AuthorEmail                         andy@highgroove.com
# AuthorName                                Andy Lindeman
# Score                                            2.4375
# LinesOfCode                                          44
# FileSizeBytes                                       969
# LastModified                        2015-12-23 22:36:32
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1790, dtype: object
# FilePath                     spec/support/ar_classes.rb
# AuthorEmail                            jko170@gmail.com
# AuthorName                                    Justin Ko
# Score                                            2.4375
# LinesOfCode                                          44
# FileSizeBytes                                       969
# LastModified                        2015-12-23 22:36:32
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1792, dtype: object
# FilePath                     spec/support/ar_classes.rb
# AuthorEmail                        dchelimsky@gmail.com
# AuthorName                              David Chelimsky
# Score                                           2.33333
# LinesOfCode                                          44
# FileSizeBytes                                       969
# LastModified                        2015-12-23 22:36:32
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1791, dtype: object
# FilePath                            spec/spec_helper.rb
# AuthorEmail                         hello@jonrowe.co.uk
# AuthorName                                     Jon Rowe
# Score                                           31.0417
# LinesOfCode                                          35
# FileSizeBytes                                       924
# LastModified                        2015-12-11 11:43:23
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1782, dtype: object
# FilePath                            spec/spec_helper.rb
# AuthorEmail                            jko170@gmail.com
# AuthorName                                    Justin Ko
# Score                                           17.5417
# LinesOfCode                                          35
# FileSizeBytes                                       924
# LastModified                        2015-12-11 11:43:23
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1783, dtype: object
# FilePath                            spec/spec_helper.rb
# AuthorEmail                  deivid.rodriguez@gmail.com
# AuthorName                              David Rodríguez
# Score                                                 9
# LinesOfCode                                          35
# FileSizeBytes                                       924
# LastModified                        2015-12-11 11:43:23
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1781, dtype: object
# FilePath                            spec/spec_helper.rb
# AuthorEmail                   samphippen@googlemail.com
# AuthorName                                  Sam Phippen
# Score                                                 9
# LinesOfCode                                          35
# FileSizeBytes                                       924
# LastModified                        2015-12-11 11:43:23
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1788, dtype: object
# FilePath                            spec/spec_helper.rb
# AuthorEmail                        dchelimsky@gmail.com
# AuthorName                              David Chelimsky
# Score                                           8.97039
# LinesOfCode                                          35
# FileSizeBytes                                       924
# LastModified                        2015-12-11 11:43:23
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1780, dtype: object
# FilePath                            spec/spec_helper.rb
# AuthorEmail                  bradley.schaefer@gmail.com
# AuthorName                             Bradley Schaefer
# Score                                             6.125
# LinesOfCode                                          35
# FileSizeBytes                                       924
# LastModified                        2015-12-11 11:43:23
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1777, dtype: object
# FilePath                            spec/spec_helper.rb
# AuthorEmail                          dave@davejlong.com
# AuthorName                                   David Long
# Score                                             6.125
# LinesOfCode                                          35
# FileSizeBytes                                       924
# LastModified                        2015-12-11 11:43:23
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1779, dtype: object
# FilePath                            spec/spec_helper.rb
# AuthorEmail                       andy@andylindeman.com
# AuthorName                                Andy Lindeman
# Score                                           3.68182
# LinesOfCode                                          35
# FileSizeBytes                                       924
# LastModified                        2015-12-11 11:43:23
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1776, dtype: object
# FilePath                            spec/spec_helper.rb
# AuthorEmail                     alex@alexrothenberg.com
# AuthorName                              Alex Rothenberg
# Score                                           2.20833
# LinesOfCode                                          35
# FileSizeBytes                                       924
# LastModified                        2015-12-11 11:43:23
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1775, dtype: object
# FilePath                            spec/spec_helper.rb
# AuthorEmail                        dan@agencyfusion.com
# AuthorName                                  Dan Rasband
# Score                                           1.87917
# LinesOfCode                                          35
# FileSizeBytes                                       924
# LastModified                        2015-12-11 11:43:23
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1778, dtype: object
# FilePath                            spec/spec_helper.rb
# AuthorEmail                      aaron.kromer@gmail.com
# AuthorName                                 Aaron Kromer
# Score                                           1.16667
# LinesOfCode                                          35
# FileSizeBytes                                       924
# LastModified                        2015-12-11 11:43:23
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1774, dtype: object
# FilePath                            spec/spec_helper.rb
# AuthorEmail                            nkymyj@gmail.com
# AuthorName                                Yuji Nakayama
# Score                                          0.555556
# LinesOfCode                                          35
# FileSizeBytes                                       924
# LastModified                        2015-12-11 11:43:23
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1786, dtype: object
# FilePath                            spec/spec_helper.rb
# AuthorEmail                     myron.marston@gmail.com
# AuthorName                                Myron Marston
# Score                                          0.462054
# LinesOfCode                                          35
# FileSizeBytes                                       924
# LastModified                        2015-12-11 11:43:23
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1785, dtype: object
# FilePath                                 spec/spec_helper.rb
# AuthorEmail      mremsik@gmail.com, ethan@ethangunderson.com
# AuthorName                   Matt Remsik and Ethan Gunderson
# Score                                                0.21875
# LinesOfCode                                               35
# FileSizeBytes                                            924
# LastModified                             2015-12-11 11:43:23
# RepoName                                         rspec-rails
# RepoUrl               git://github.com/rspec/rspec-rails.git
# Name: 1784, dtype: object
# FilePath                            spec/spec_helper.rb
# AuthorEmail                          rr.rosas@gmail.com
# AuthorName                      Rodrigo Rosenfeld Rosas
# Score                                          0.140625
# LinesOfCode                                          35
# FileSizeBytes                                       924
# LastModified                        2015-12-11 11:43:23
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1787, dtype: object
# FilePath                            spec/spec_helper.rb
# AuthorEmail                             xavier@rhnh.net
# AuthorName                                  Xavier Shay
# Score                                          0.107143
# LinesOfCode                                          35
# FileSizeBytes                                       924
# LastModified                        2015-12-11 11:43:23
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1789, dtype: object
# FilePath                      spec/sanity_check_spec.rb
# AuthorEmail                      aaron.kromer@gmail.com
# AuthorName                                 Aaron Kromer
# Score                                              8.25
# LinesOfCode                                          47
# FileSizeBytes                                      1311
# LastModified                        2017-11-14 16:58:30
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1771, dtype: object
# FilePath                      spec/sanity_check_spec.rb
# AuthorEmail       mattbrictson@users.noreply.github.com
# AuthorName                                Matt Brictson
# Score                                                 8
# LinesOfCode                                          47
# FileSizeBytes                                      1311
# LastModified                        2017-11-14 16:58:30
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1772, dtype: object
# FilePath                      spec/sanity_check_spec.rb
# AuthorEmail                   samphippen@googlemail.com
# AuthorName                                  Sam Phippen
# Score                                               2.5
# LinesOfCode                                          47
# FileSizeBytes                                      1311
# LastModified                        2017-11-14 16:58:30
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1773, dtype: object
# FilePath                       spec/rspec/rails_spec.rb
# AuthorEmail                      aaron.kromer@gmail.com
# AuthorName                                 Aaron Kromer
# Score                                                26
# LinesOfCode                                          26
# FileSizeBytes                                       733
# LastModified                        2015-08-02 14:31:06
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1769, dtype: object
# FilePath                       spec/rspec/rails_spec.rb
# AuthorEmail                alexander.egan@customink.com
# AuthorName                                    Alex Egan
# Score                                                26
# LinesOfCode                                          26
# FileSizeBytes                                       733
# LastModified                        2015-08-02 14:31:06
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1770, dtype: object
# FilePath         spec/rspec/rails/view_spec_methods_spec.rb
# AuthorEmail                         rclark.sf+git@gmail.com
# AuthorName                                       Ryan Clark
# Score                                                    72
# LinesOfCode                                              72
# FileSizeBytes                                          2149
# LastModified                            2015-12-17 09:17:42
# RepoName                                        rspec-rails
# RepoUrl              git://github.com/rspec/rspec-rails.git
# Name: 1767, dtype: object
# FilePath         spec/rspec/rails/view_spec_methods_spec.rb
# AuthorEmail                       samphippen@googlemail.com
# AuthorName                                      Sam Phippen
# Score                                                    72
# LinesOfCode                                              72
# FileSizeBytes                                          2149
# LastModified                            2015-12-17 09:17:42
# RepoName                                        rspec-rails
# RepoUrl              git://github.com/rspec/rspec-rails.git
# Name: 1768, dtype: object
# FilePath         spec/rspec/rails/view_rendering_spec.rb
# AuthorEmail                           mail@jonrowe.co.uk
# AuthorName                                      Jon Rowe
# Score                                            47.1667
# LinesOfCode                                          190
# FileSizeBytes                                       5736
# LastModified                         2018-07-09 05:31:11
# RepoName                                     rspec-rails
# RepoUrl           git://github.com/rspec/rspec-rails.git
# Name: 1761, dtype: object
# FilePath         spec/rspec/rails/view_rendering_spec.rb
# AuthorEmail                        pavel.rosicky@easy.cz
# AuthorName                                         pavel
# Score                                                 42
# LinesOfCode                                          190
# FileSizeBytes                                       5736
# LastModified                         2018-07-09 05:31:11
# RepoName                                     rspec-rails
# RepoUrl           git://github.com/rspec/rspec-rails.git
# Name: 1764, dtype: object
# FilePath         spec/rspec/rails/view_rendering_spec.rb
# AuthorEmail                        andy@andylindeman.com
# AuthorName                                 Andy Lindeman
# Score                                            36.3225
# LinesOfCode                                          190
# FileSizeBytes                                       5736
# LastModified                         2018-07-09 05:31:11
# RepoName                                     rspec-rails
# RepoUrl           git://github.com/rspec/rspec-rails.git
# Name: 1755, dtype: object
# FilePath         spec/rspec/rails/view_rendering_spec.rb
# AuthorEmail                          hello@jonrowe.co.uk
# AuthorName                                      Jon Rowe
# Score                                            29.5952
# LinesOfCode                                          190
# FileSizeBytes                                       5736
# LastModified                         2018-07-09 05:31:11
# RepoName                                     rspec-rails
# RepoUrl           git://github.com/rspec/rspec-rails.git
# Name: 1759, dtype: object
# FilePath         spec/rspec/rails/view_rendering_spec.rb
# AuthorEmail                                sj26@sj26.com
# AuthorName                                Samuel Cochran
# Score                                                 28
# LinesOfCode                                          190
# FileSizeBytes                                       5736
# LastModified                         2018-07-09 05:31:11
# RepoName                                     rspec-rails
# RepoUrl           git://github.com/rspec/rspec-rails.git
# Name: 1766, dtype: object
# FilePath         spec/rspec/rails/view_rendering_spec.rb
# AuthorEmail                      myron.marston@gmail.com
# AuthorName                                 Myron Marston
# Score                                            15.3333
# LinesOfCode                                          190
# FileSizeBytes                                       5736
# LastModified                         2018-07-09 05:31:11
# RepoName                                     rspec-rails
# RepoUrl           git://github.com/rspec/rspec-rails.git
# Name: 1763, dtype: object
# FilePath         spec/rspec/rails/view_rendering_spec.rb
# AuthorEmail                           andy@andymorris.cc
# AuthorName                                   Andy Morris
# Score                                            5.83333
# LinesOfCode                                          190
# FileSizeBytes                                       5736
# LastModified                         2018-07-09 05:31:11
# RepoName                                     rspec-rails
# RepoUrl           git://github.com/rspec/rspec-rails.git
# Name: 1756, dtype: object
# FilePath         spec/rspec/rails/view_rendering_spec.rb
# AuthorEmail                    samphippen@googlemail.com
# AuthorName                                   Sam Phippen
# Score                                            5.83333
# LinesOfCode                                          190
# FileSizeBytes                                       5736
# LastModified                         2018-07-09 05:31:11
# RepoName                                     rspec-rails
# RepoUrl           git://github.com/rspec/rspec-rails.git
# Name: 1765, dtype: object
# FilePath         spec/rspec/rails/view_rendering_spec.rb
# AuthorEmail                         dchelimsky@gmail.com
# AuthorName                               David Chelimsky
# Score                                            3.38333
# LinesOfCode                                          190
# FileSizeBytes                                       5736
# LastModified                         2018-07-09 05:31:11
# RepoName                                     rspec-rails
# RepoUrl           git://github.com/rspec/rspec-rails.git
# Name: 1758, dtype: object
# FilePath         spec/rspec/rails/view_rendering_spec.rb
# AuthorEmail                        benjamin@quorning.net
# AuthorName                             Benjamin Quorning
# Score                                            2.16667
# LinesOfCode                                          190
# FileSizeBytes                                       5736
# LastModified                         2018-07-09 05:31:11
# RepoName                                     rspec-rails
# RepoUrl           git://github.com/rspec/rspec-rails.git
# Name: 1757, dtype: object
# FilePath         spec/rspec/rails/view_rendering_spec.rb
# AuthorEmail                             jko170@gmail.com
# AuthorName                                     Justin Ko
# Score                                                  2
# LinesOfCode                                          190
# FileSizeBytes                                       5736
# LastModified                         2018-07-09 05:31:11
# RepoName                                     rspec-rails
# RepoUrl           git://github.com/rspec/rspec-rails.git
# Name: 1760, dtype: object
# FilePath         spec/rspec/rails/view_rendering_spec.rb
# AuthorEmail                               martin@lite.nu
# AuthorName                                 Martin Svalin
# Score                                                  2
# LinesOfCode                                          190
# FileSizeBytes                                       5736
# LastModified                         2018-07-09 05:31:11
# RepoName                                     rspec-rails
# RepoUrl           git://github.com/rspec/rspec-rails.git
# Name: 1762, dtype: object
# FilePath         spec/rspec/rails/setup_and_teardown_adapter_sp...
# AuthorEmail                                  mfazekas@szemafor.com
# AuthorName                                          Miklos Fazekas
# Score                                                           31
# LinesOfCode                                                     49
# FileSizeBytes                                                 1888
# LastModified                                   2016-04-14 09:56:37
# RepoName                                               rspec-rails
# RepoUrl                     git://github.com/rspec/rspec-rails.git
# Name: 1753, dtype: object
# FilePath         spec/rspec/rails/setup_and_teardown_adapter_sp...
# AuthorEmail                              samphippen@googlemail.com
# AuthorName                                             Sam Phippen
# Score                                                           31
# LinesOfCode                                                     49
# FileSizeBytes                                                 1888
# LastModified                                   2016-04-14 09:56:37
# RepoName                                               rspec-rails
# RepoUrl                     git://github.com/rspec/rspec-rails.git
# Name: 1754, dtype: object
# FilePath         spec/rspec/rails/setup_and_teardown_adapter_sp...
# AuthorEmail                                  andy@andylindeman.com
# AuthorName                                           Andy Lindeman
# Score                                                      3.18182
# LinesOfCode                                                     49
# FileSizeBytes                                                 1888
# LastModified                                   2016-04-14 09:56:37
# RepoName                                               rspec-rails
# RepoUrl                     git://github.com/rspec/rspec-rails.git
# Name: 1750, dtype: object
# FilePath         spec/rspec/rails/setup_and_teardown_adapter_sp...
# AuthorEmail                                    hello@jonrowe.co.uk
# AuthorName                                                Jon Rowe
# Score                                                      3.18182
# LinesOfCode                                                     49
# FileSizeBytes                                                 1888
# LastModified                                   2016-04-14 09:56:37
# RepoName                                               rspec-rails
# RepoUrl                     git://github.com/rspec/rspec-rails.git
# Name: 1752, dtype: object
# FilePath         spec/rspec/rails/setup_and_teardown_adapter_sp...
# AuthorEmail                                   dchelimsky@gmail.com
# AuthorName                                         David Chelimsky
# Score                                                     0.264463
# LinesOfCode                                                     49
# FileSizeBytes                                                 1888
# LastModified                                   2016-04-14 09:56:37
# RepoName                                               rspec-rails
# RepoUrl                     git://github.com/rspec/rspec-rails.git
# Name: 1751, dtype: object
# FilePath         spec/rspec/rails/minitest_lifecycle_adapter_sp...
# AuthorEmail                                    alindeman@gmail.com
# AuthorName                                           Andy Lindeman
# Score                                                           22
# LinesOfCode                                                     31
# FileSizeBytes                                                 1059
# LastModified                                   2014-06-15 12:26:59
# RepoName                                               rspec-rails
# RepoUrl                     git://github.com/rspec/rspec-rails.git
# Name: 1745, dtype: object
# FilePath         spec/rspec/rails/minitest_lifecycle_adapter_sp...
# AuthorEmail                                 aaron.kromer@gmail.com
# AuthorName                                            Aaron Kromer
# Score                                                           16
# LinesOfCode                                                     31
# FileSizeBytes                                                 1059
# LastModified                                   2014-06-15 12:26:59
# RepoName                                               rspec-rails
# RepoUrl                     git://github.com/rspec/rspec-rails.git
# Name: 1744, dtype: object
# FilePath         spec/rspec/rails/minitest_lifecycle_adapter_sp...
# AuthorEmail                      bradley.schaefer+github@gmail.com
# AuthorName                                        Bradley Schaefer
# Score                                                      11.1429
# LinesOfCode                                                     31
# FileSizeBytes                                                 1059
# LastModified                                   2014-06-15 12:26:59
# RepoName                                               rspec-rails
# RepoUrl                     git://github.com/rspec/rspec-rails.git
# Name: 1747, dtype: object
# FilePath         spec/rspec/rails/minitest_lifecycle_adapter_sp...
# AuthorEmail                             bradley.schaefer@gmail.com
# AuthorName                                        Bradley Schaefer
# Score                                                      11.1429
# LinesOfCode                                                     31
# FileSizeBytes                                                 1059
# LastModified                                   2014-06-15 12:26:59
# RepoName                                               rspec-rails
# RepoUrl                     git://github.com/rspec/rspec-rails.git
# Name: 1748, dtype: object
# FilePath         spec/rspec/rails/minitest_lifecycle_adapter_sp...
# AuthorEmail                                  andy@andylindeman.com
# AuthorName                                           Andy Lindeman
# Score                                                          3.9
# LinesOfCode                                                     31
# FileSizeBytes                                                 1059
# LastModified                                   2014-06-15 12:26:59
# RepoName                                               rspec-rails
# RepoUrl                     git://github.com/rspec/rspec-rails.git
# Name: 1746, dtype: object
# FilePath         spec/rspec/rails/minitest_lifecycle_adapter_sp...
# AuthorEmail                                     patrick@vanstee.me
# AuthorName                                                 vanstee
# Score                                                          3.9
# LinesOfCode                                                     31
# FileSizeBytes                                                 1059
# LastModified                                   2014-06-15 12:26:59
# RepoName                                               rspec-rails
# RepoUrl                     git://github.com/rspec/rspec-rails.git
# Name: 1749, dtype: object
# FilePath         spec/rspec/rails/matchers/route_to_spec.rb
# AuthorEmail                            dchelimsky@gmail.com
# AuthorName                                  David Chelimsky
# Score                                               82.8147
# LinesOfCode                                             160
# FileSizeBytes                                          5532
# LastModified                            2016-06-14 07:16:25
# RepoName                                        rspec-rails
# RepoUrl              git://github.com/rspec/rspec-rails.git
# Name: 1737, dtype: object
# FilePath         spec/rspec/rails/matchers/route_to_spec.rb
# AuthorEmail                             hello@jonrowe.co.uk
# AuthorName                                         Jon Rowe
# Score                                               30.6061
# LinesOfCode                                             160
# FileSizeBytes                                          5532
# LastModified                            2016-06-14 07:16:25
# RepoName                                        rspec-rails
# RepoUrl              git://github.com/rspec/rspec-rails.git
# Name: 1738, dtype: object
# FilePath         spec/rspec/rails/matchers/route_to_spec.rb
# AuthorEmail                             alindeman@gmail.com
# AuthorName                                    Andy Lindeman
# Score                                               29.8636
# LinesOfCode                                             160
# FileSizeBytes                                          5532
# LastModified                            2016-06-14 07:16:25
# RepoName                                        rspec-rails
# RepoUrl              git://github.com/rspec/rspec-rails.git
# Name: 1735, dtype: object
# FilePath         spec/rspec/rails/matchers/route_to_spec.rb
# AuthorEmail                              mail@jonrowe.co.uk
# AuthorName                                         Jon Rowe
# Score                                                    20
# LinesOfCode                                             160
# FileSizeBytes                                          5532
# LastModified                            2016-06-14 07:16:25
# RepoName                                        rspec-rails
# RepoUrl              git://github.com/rspec/rspec-rails.git
# Name: 1741, dtype: object
# FilePath         spec/rspec/rails/matchers/route_to_spec.rb
# AuthorEmail                              tiwatson@gmail.com
# AuthorName                                       Tim Watson
# Score                                               18.8182
# LinesOfCode                                             160
# FileSizeBytes                                          5532
# LastModified                            2016-06-14 07:16:25
# RepoName                                        rspec-rails
# RepoUrl              git://github.com/rspec/rspec-rails.git
# Name: 1743, dtype: object
# FilePath         spec/rspec/rails/matchers/route_to_spec.rb
# AuthorEmail                          aaron.kromer@gmail.com
# AuthorName                                     Aaron Kromer
# Score                                                    12
# LinesOfCode                                             160
# FileSizeBytes                                          5532
# LastModified                            2016-06-14 07:16:25
# RepoName                                        rspec-rails
# RepoUrl              git://github.com/rspec/rspec-rails.git
# Name: 1734, dtype: object
# FilePath         spec/rspec/rails/matchers/route_to_spec.rb
# AuthorEmail                           andy@andylindeman.com
# AuthorName                                    Andy Lindeman
# Score                                               11.4424
# LinesOfCode                                             160
# FileSizeBytes                                          5532
# LastModified                            2016-06-14 07:16:25
# RepoName                                        rspec-rails
# RepoUrl              git://github.com/rspec/rspec-rails.git
# Name: 1736, dtype: object
# FilePath         spec/rspec/rails/matchers/route_to_spec.rb
# AuthorEmail                            joe@faithfulgeek.org
# AuthorName                                      Joe Fiorini
# Score                                               6.54545
# LinesOfCode                                             160
# FileSizeBytes                                          5532
# LastModified                            2016-06-14 07:16:25
# RepoName                                        rspec-rails
# RepoUrl              git://github.com/rspec/rspec-rails.git
# Name: 1739, dtype: object
# FilePath         spec/rspec/rails/matchers/route_to_spec.rb
# AuthorEmail                              johnw@orcasnet.com
# AuthorName                                       John Wulff
# Score                                               1.30909
# LinesOfCode                                             160
# FileSizeBytes                                          5532
# LastModified                            2016-06-14 07:16:25
# RepoName                                        rspec-rails
# RepoUrl              git://github.com/rspec/rspec-rails.git
# Name: 1740, dtype: object
# FilePath         spec/rspec/rails/matchers/route_to_spec.rb
# AuthorEmail                             marc.weil@gmail.com
# AuthorName                                        Marc Weil
# Score                                              0.949495
# LinesOfCode                                             160
# FileSizeBytes                                          5532
# LastModified                            2016-06-14 07:16:25
# RepoName                                        rspec-rails
# RepoUrl              git://github.com/rspec/rspec-rails.git
# Name: 1742, dtype: object
# FilePath         spec/rspec/rails/matchers/relation_match_array...
# AuthorEmail                                  andy@andylindeman.com
# AuthorName                                           Andy Lindeman
# Score                                                           51
# LinesOfCode                                                     31
# FileSizeBytes                                                 1131
# LastModified                                   2013-12-08 15:34:55
# RepoName                                               rspec-rails
# RepoUrl                     git://github.com/rspec/rspec-rails.git
# Name: 1728, dtype: object
# FilePath         spec/rspec/rails/matchers/relation_match_array...
# AuthorEmail                                    alindeman@gmail.com
# AuthorName                                           Andy Lindeman
# Score                                                      35.5556
# LinesOfCode                                                     31
# FileSizeBytes                                                 1131
# LastModified                                   2013-12-08 15:34:55
# RepoName                                               rspec-rails
# RepoUrl                     git://github.com/rspec/rspec-rails.git
# Name: 1727, dtype: object
# FilePath         spec/rspec/rails/matchers/relation_match_array...
# AuthorEmail                                    hello@jonrowe.co.uk
# AuthorName                                                Jon Rowe
# Score                                                           30
# LinesOfCode                                                     31
# FileSizeBytes                                                 1131
# LastModified                                   2013-12-08 15:34:55
# RepoName                                               rspec-rails
# RepoUrl                     git://github.com/rspec/rspec-rails.git
# Name: 1731, dtype: object
# FilePath         spec/rspec/rails/matchers/relation_match_array...
# AuthorEmail                                       jko170@gmail.com
# AuthorName                                               Justin Ko
# Score                                                      12.1111
# LinesOfCode                                                     31
# FileSizeBytes                                                 1131
# LastModified                                   2013-12-08 15:34:55
# RepoName                                               rspec-rails
# RepoUrl                     git://github.com/rspec/rspec-rails.git
# Name: 1732, dtype: object
# FilePath         spec/rspec/rails/matchers/relation_match_array...
# AuthorEmail                                    saurastar@gmail.com
# AuthorName                                            Carlos Saura
# Score                                                      2.33333
# LinesOfCode                                                     31
# FileSizeBytes                                                 1131
# LastModified                                   2013-12-08 15:34:55
# RepoName                                               rspec-rails
# RepoUrl                     git://github.com/rspec/rspec-rails.git
# Name: 1733, dtype: object
# FilePath         spec/rspec/rails/matchers/relation_match_array...
# AuthorEmail                                    andy@highgroove.com
# AuthorName                                           Andy Lindeman
# Score                                                      2.11111
# LinesOfCode                                                     31
# FileSizeBytes                                                 1131
# LastModified                                   2013-12-08 15:34:55
# RepoName                                               rspec-rails
# RepoUrl                     git://github.com/rspec/rspec-rails.git
# Name: 1729, dtype: object
# FilePath         spec/rspec/rails/matchers/relation_match_array...
# AuthorEmail                                   dchelimsky@gmail.com
# AuthorName                                         David Chelimsky
# Score                                                      1.33333
# LinesOfCode                                                     31
# FileSizeBytes                                                 1131
# LastModified                                   2013-12-08 15:34:55
# RepoName                                               rspec-rails
# RepoUrl                     git://github.com/rspec/rspec-rails.git
# Name: 1730, dtype: object
# FilePath         spec/rspec/rails/matchers/redirect_to_spec.rb
# AuthorEmail                                 mail@jonrowe.co.uk
# AuthorName                                            Jon Rowe
# Score                                                      162
# LinesOfCode                                                 81
# FileSizeBytes                                             2114
# LastModified                               2016-06-14 07:16:25
# RepoName                                           rspec-rails
# RepoUrl                 git://github.com/rspec/rspec-rails.git
# Name: 1724, dtype: object
# FilePath         spec/rspec/rails/matchers/redirect_to_spec.rb
# AuthorEmail                               dchelimsky@gmail.com
# AuthorName                                     David Chelimsky
# Score                                                  149.577
# LinesOfCode                                                 81
# FileSizeBytes                                             2114
# ...
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 26, dtype: object
# FilePath                        .rubocop_rspec_base.yml
# AuthorEmail                      benoit@hopsandfork.com
# AuthorName                                Benoit Tigeot
# Score                                           202.286
# LinesOfCode                                         309
# FileSizeBytes                                      6465
# LastModified                        2019-04-02 03:41:15
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 22, dtype: object
# FilePath                        .rubocop_rspec_base.yml
# AuthorEmail                     myron.marston@gmail.com
# AuthorName                                Myron Marston
# Score                                           22.6232
# LinesOfCode                                         309
# FileSizeBytes                                      6465
# LastModified                        2019-04-02 03:41:15
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 27, dtype: object
# FilePath                        .rubocop_rspec_base.yml
# AuthorEmail                      aaron.kromer@gmail.com
# AuthorName                                 Aaron Kromer
# Score                                            16.375
# LinesOfCode                                         309
# FileSizeBytes                                      6465
# LastModified                        2019-04-02 03:41:15
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 20, dtype: object
# FilePath                        .rubocop_rspec_base.yml
# AuthorEmail                            nkymyj@gmail.com
# AuthorName                                Yuji Nakayama
# Score                                            12.602
# LinesOfCode                                         309
# FileSizeBytes                                      6465
# LastModified                        2019-04-02 03:41:15
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 29, dtype: object
# FilePath                        .rubocop_rspec_base.yml
# AuthorEmail                         hello@jonrowe.co.uk
# AuthorName                                     Jon Rowe
# Score                                           8.89873
# LinesOfCode                                         309
# FileSizeBytes                                      6465
# LastModified                        2019-04-02 03:41:15
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 24, dtype: object
# FilePath                        .rubocop_rspec_base.yml
# AuthorEmail                      olle.jonsson@gmail.com
# AuthorName                                 Olle Jonsson
# Score                                                 5
# LinesOfCode                                         309
# FileSizeBytes                                      6465
# LastModified                        2019-04-02 03:41:15
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 30, dtype: object
# FilePath                        .rubocop_rspec_base.yml
# AuthorEmail                   josh.kalderimis@gmail.com
# AuthorName                              Josh Kalderimis
# Score                                            2.5102
# LinesOfCode                                         309
# FileSizeBytes                                      6465
# LastModified                        2019-04-02 03:41:15
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 25, dtype: object
# FilePath                        .rubocop_rspec_base.yml
# AuthorEmail           bradley.schaefer+github@gmail.com
# AuthorName                             Bradley Schaefer
# Score                                           1.42857
# LinesOfCode                                         309
# FileSizeBytes                                      6465
# LastModified                        2019-04-02 03:41:15
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 23, dtype: object
# FilePath                        .rubocop_rspec_base.yml
# AuthorEmail                  nikki.liz.murray@gmail.com
# AuthorName                                 Nikki Murray
# Score                                          0.982143
# LinesOfCode                                         309
# FileSizeBytes                                      6465
# LastModified                        2019-04-02 03:41:15
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 28, dtype: object
# FilePath                        .rubocop_rspec_base.yml
# AuthorEmail                             ben@mossity.com
# AuthorName                                     Ben Moss
# Score                                          0.952381
# LinesOfCode                                         309
# FileSizeBytes                                      6465
# LastModified                        2019-04-02 03:41:15
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 21, dtype: object
# FilePath                                   .rubocop.yml
# AuthorEmail                      aaron.kromer@gmail.com
# AuthorName                                 Aaron Kromer
# Score                                               239
# LinesOfCode                                          45
# FileSizeBytes                                      1423
# LastModified                        2014-08-19 06:04:07
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 17, dtype: object
# FilePath                                   .rubocop.yml
# AuthorEmail                         hello@jonrowe.co.uk
# AuthorName                                     Jon Rowe
# Score                                               239
# LinesOfCode                                          45
# FileSizeBytes                                      1423
# LastModified                        2014-08-19 06:04:07
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 18, dtype: object
# FilePath                                   .rubocop.yml
# AuthorEmail                   josh.kalderimis@gmail.com
# AuthorName                              Josh Kalderimis
# Score                                               142
# LinesOfCode                                          45
# FileSizeBytes                                      1423
# LastModified                        2014-08-19 06:04:07
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 19, dtype: object
# FilePath                                         .rspec
# AuthorEmail                      aaron.kromer@gmail.com
# AuthorName                                 Aaron Kromer
# Score                                                 8
# LinesOfCode                                           3
# FileSizeBytes                                        41
# LastModified                        2015-05-25 12:27:14
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 14, dtype: object
# FilePath                                         .rspec
# AuthorEmail                         hello@jonrowe.co.uk
# AuthorName                                     Jon Rowe
# Score                                               1.6
# LinesOfCode                                           3
# FileSizeBytes                                        41
# LastModified                        2015-05-25 12:27:14
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 16, dtype: object
# FilePath                                         .rspec
# AuthorEmail                        dchelimsky@gmail.com
# AuthorName                              David Chelimsky
# Score                                               0.8
# LinesOfCode                                           3
# FileSizeBytes                                        41
# LastModified                        2015-05-25 12:27:14
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 15, dtype: object
# FilePath                                     .gitignore
# AuthorEmail                        dchelimsky@gmail.com
# AuthorName                              David Chelimsky
# Score                                             30.63
# LinesOfCode                                          24
# FileSizeBytes                                       238
# LastModified                        2015-07-10 01:11:30
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 8, dtype: object
# FilePath                                     .gitignore
# AuthorEmail                      aaron.kromer@gmail.com
# AuthorName                                 Aaron Kromer
# Score                                           5.71429
# LinesOfCode                                          24
# FileSizeBytes                                       238
# LastModified                        2015-07-10 01:11:30
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 4, dtype: object
# FilePath                                     .gitignore
# AuthorEmail                       andy@andylindeman.com
# AuthorName                                Andy Lindeman
# Score                                           4.86111
# LinesOfCode                                          24
# FileSizeBytes                                       238
# LastModified                        2015-07-10 01:11:30
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 7, dtype: object
# FilePath                                     .gitignore
# AuthorEmail                     myron.marston@gmail.com
# AuthorName                                Myron Marston
# Score                                           4.20833
# LinesOfCode                                          24
# FileSizeBytes                                       238
# LastModified                        2015-07-10 01:11:30
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 11, dtype: object
# FilePath                                     .gitignore
# AuthorEmail                         hello@jonrowe.co.uk
# AuthorName                                     Jon Rowe
# Score                                           3.33333
# LinesOfCode                                          24
# FileSizeBytes                                       238
# LastModified                        2015-07-10 01:11:30
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 9, dtype: object
# FilePath                                     .gitignore
# AuthorEmail                          mail@jonrowe.co.uk
# AuthorName                                     Jon Rowe
# Score                                           3.33333
# LinesOfCode                                          24
# FileSizeBytes                                       238
# LastModified                        2015-07-10 01:11:30
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 10, dtype: object
# FilePath                                     .gitignore
# AuthorEmail                              thom@sfedb.com
# AuthorName                        Thomas Drake-Brockman
# Score                                           1.52778
# LinesOfCode                                          24
# FileSizeBytes                                       238
# LastModified                        2015-07-10 01:11:30
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 12, dtype: object
# FilePath                                     .gitignore
# AuthorEmail                         alindeman@gmail.com
# AuthorName                                Andy Lindeman
# Score                                          0.952381
# LinesOfCode                                          24
# FileSizeBytes                                       238
# LastModified                        2015-07-10 01:11:30
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 5, dtype: object
# FilePath                                     .gitignore
# AuthorEmail                       ywen.github@gmail.com
# AuthorName                                       Yi Wen
# Score                                          0.952381
# LinesOfCode                                          24
# FileSizeBytes                                       238
# LastModified                        2015-07-10 01:11:30
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 13, dtype: object
# FilePath                                     .gitignore
# AuthorEmail                       andersonlfl@gmail.com
# AuthorName                                andersonleite
# Score                                          0.444444
# LinesOfCode                                          24
# FileSizeBytes                                       238
# LastModified                        2015-07-10 01:11:30
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 6, dtype: object
# FilePath                                      .document
# AuthorEmail                          mail@jonrowe.co.uk
# AuthorName                                     Jon Rowe
# Score                                                12
# LinesOfCode                                           5
# FileSizeBytes                                        48
# LastModified                        2015-10-07 01:15:13
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 2, dtype: object
# FilePath                                      .document
# AuthorEmail                         hello@jonrowe.co.uk
# AuthorName                                     Jon Rowe
# Score                                                 6
# LinesOfCode                                           5
# FileSizeBytes                                        48
# LastModified                        2015-10-07 01:15:13
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 1, dtype: object
# FilePath                                      .document
# AuthorEmail                        w.wnetrzak@gmail.com
# AuthorName                            Wojciech Wnętrzak
# Score                                                 6
# LinesOfCode                                           5
# FileSizeBytes                                        48
# LastModified                        2015-10-07 01:15:13
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 3, dtype: object
# FilePath                                      .document
# AuthorEmail                        dchelimsky@gmail.com
# AuthorName                              David Chelimsky
# Score                                            4.3125
# LinesOfCode                                           5
# FileSizeBytes                                        48
# LastModified                        2015-10-07 01:15:13
# RepoName                                    rspec-rails
# RepoUrl          git://github.com/rspec/rspec-rails.git
# Name: 0, dtype: object
