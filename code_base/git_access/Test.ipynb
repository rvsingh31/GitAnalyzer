# %%
import Use_Case
import os
import pandas as pd

# %%
repo_owner = 'mochajs'
git_url = 'git://github.com/mochajs/mocha.git'
repo_name = 'mocha'

# %%
ucase1 = Use_Case.Use_Case(repo_owner,repo_name,git_url)
# Out:
# d6a539ee2b083fcf5603d2bd61bc721c8c7bf11d

# %%
uc1 = ucase1.UC1()
print(uc1.columns)
# Out:
# Index(['FilePath', 'AuthorEmail', 'AuthorName', 'Score', 'LinesOfCode',
#        'FileSizeBytes', 'LastModified', 'RepoName', 'RepoUrl'],
#       dtype='object')

# %%
uc2 = ucase1.UC2()

# %%
uc3 = ucase1.UC3()

# %%
for _,row in uc1.iterrows():
    print(row['RepoName'])
# Out:
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# mocha
# ...
